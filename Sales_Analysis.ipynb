# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
pd.set_option('display.max_columns', None)

# %%
os.getcwd()
# Out:
# '/Users/mhausch/Data/Financial'

# %%
#conda install openpyxl

# %%
raw_import = pd.read_excel("./Input/July_2022.xlsm", sheet_name = 0)

# %%
type(raw_import)
# Out:
# pandas.core.frame.DataFrame

# %%
raw_import.head()
# Out:
#   Accession # Modified Accession # Sub-region        Type  \
# 0             A0001325      A01325   Americas  Commercial
# 1             A0001507      A01507     Europe  Commercial
# 2             A0002587      A02587     Europe  Commercial
# 3             A0003086      A03086     Europe  Commercial
# 4             A0006273      A06273     Europe  Commercial
#
#   Account: Reporting Country (just for our use) Account: Reporting Country  \
# 0                                        CANADA                         CA
# 1                                         SPAIN                         ES
# 2                                         SPAIN                         ES
# 3                                         SPAIN                         ES
# 4                                         ITALY                         IT
#
#   Account: Reporting City        Billing Type         Billing Type.1  \
# 0                Hamilton   Private Insurance       Patient Self-Pay
# ...

# %%
raw_import.shape
# Out:
# (17944, 39)

# %%
raw_import.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17944 entries, 0 to 17943
# Data columns (total 39 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Accession # Modified                                            17944 non-null  object
#  1   Accession #                                                     17944 non-null  object
#  2   Sub-region                                                      17944 non-null  object
#  3   Type                                                            17944 non-null  object
#  4   Account: Reporting Country (just for our use)                   17944 non-null  object
#  5   Account: Reporting Country                                      17944 non-null  object
#  6   Account: Reporting City                                         17943 non-null  object
# ...

# %%
raw_import.columns
# Out:
# Index(['Accession # Modified', 'Accession #', 'Sub-region', 'Type',
#        'Account: Reporting Country (just for our use)',
#        'Account: Reporting Country', 'Account: Reporting City', 'Billing Type',
#        'Billing Type.1', 'LIMS Project ID',
#        'Institution (derived from account by Marina)', 'Account: Account Name',
#        'Contact: Full Name', 'Contact: Full Name.1', 'Date Received',
#        'Month received', 'Date received', 'Quarter received', 'Year received',
#        'Final report', 'POD Date', 'POD Month', 'POD Quarter', 'POD Year',
#        'Expanded study code (Company XXX Biomarker YYY Study name ZZZ)',
#        'Test type', 'Patient: Primary Insurance Company Name: Account Name',
#        'AE/N', 'Currency', 'Price', 'Exchange rate', 'Comm Price in USD',
#        'GAP IST Biopharma Price in USD', 'Free of charge', 'Listed price',
#        'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38'],
#       dtype='object')

# %%
import_relevant_list = ['Accession #', 'Sub-region', 'Type',
       'Account: Reporting Country (just for our use)',
       'Billing Type.1', 'LIMS Project ID',
       'Institution (derived from account by Marina)', 'Account: Account Name',
       'Contact: Full Name','Date Received',
       'Month received', 'Date received', 'Quarter received', 'Year received','Test type', 'Patient: Primary Insurance Company Name: Account Name',
       'AE/N', 'Currency', 'Price', 'Exchange rate', 'Comm Price in USD',
       'GAP IST Biopharma Price in USD', 'Free of charge', 'Listed price',
       'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38']

# %%
raw_import_df = raw_import.loc[:, import_relevant_list]

# %%
df = raw_import_df.rename(columns ={'Accession #' : 'Accession_#', 'Account: Reporting Country (just for our use)': 'Reporting_Country', 'Account: Account Name':'Account', 'Comm Price in USD':'USD_Price', 'Free of charge':'FOC', 'Unnamed: 35':'Cancer_type', 'Institution (derived from account by Marina)':'Institute', 'Contact: Full Name':'Full_name',
                                   'Sub-region':'Region',
                                   'Billing Type.1':'Billing_Type'})

# %%
df.columns
# Out:
# Index(['Accession_#', 'Region', 'Type', 'Reporting_Country', 'Billing Type',
#        'Billing_Type', 'LIMS Project ID', 'Institute', 'Account', 'Full_name',
#        'Date Received', 'Month received', 'Date received', 'Quarter received',
#        'Year received', 'Test type',
#        'Patient: Primary Insurance Company Name: Account Name', 'AE/N',
#        'Currency', 'Price', 'Exchange rate', 'USD_Price',
#        'GAP IST Biopharma Price in USD', 'FOC', 'Listed price', 'Cancer_type',
#        'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17944 entries, 0 to 17943
# Data columns (total 29 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Accession_#                                            17944 non-null  object
#  1   Region                                                 17944 non-null  object
#  2   Type                                                   17944 non-null  object
#  3   Reporting_Country                                      17944 non-null  object
#  4   Billing Type                                           17944 non-null  object
#  5   Billing_Type                                           17919 non-null  object
#  6   LIMS Project ID                                        17944 non-null  object
#  7   Institute                                              17944 non-null  object
# ...

# %%
df["Date"] = pd.to_datetime(df['Date Received'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17944 entries, 0 to 17943
# Data columns (total 30 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Accession_#                                            17944 non-null  object
#  1   Region                                                 17944 non-null  object
#  2   Type                                                   17944 non-null  object
#  3   Reporting_Country                                      17944 non-null  object
#  4   Billing Type                                           17944 non-null  object
#  5   Billing_Type                                           17919 non-null  object
#  6   LIMS Project ID                                        17944 non-null  object
#  7   Institute                                              17944 non-null  object
# ...

# %%
df.head()
# Out:
#   Accession_#    Region        Type Reporting_Country        Billing Type  \
# 0      A01325  Americas  Commercial            CANADA   Private Insurance
# 1      A01507    Europe  Commercial             SPAIN  Distributors : ROW
# 2      A02587    Europe  Commercial             SPAIN  Distributors : ROW
# 3      A03086    Europe  Commercial             SPAIN  Distributors : ROW
# 4      A06273    Europe  Commercial             ITALY   Private Insurance
#
#             Billing_Type LIMS Project ID                 Institute  \
# 0       Patient Self-Pay          GHI_01  Juravinski Cancer Centre
# 1  Institutional Billing          GHI_01                   OncoDNA
# 2  Institutional Billing          GHI_01                   OncoDNA
# 3  Institutional Billing          GHI_01                   OncoDNA
# 4       Patient Self-Pay          GHI_01       S Raffaele Hospital
#
#                     Account        Full_name Date Received Month received  \
# ...

# %%
df['Billing_Type'].value_counts()
# Out:
# Pharma : ROW                              6944
# Pharma : US                               2595
# Distributors : ROW                        2175
# Self-Pay Patient                          1607
# Do Not Bill - LUNAR                       1154
# Do Not Bill - Cancelled                    676
# Clinical Trial : ROW                       645
# Do Not Bill - ROW                          565
# Do Not Bill - Medical Affairs              507
# Research : ROW                             491
# Self-Pay Sponsored                         427
# Do Not Bill - Promotional                   62
# Institutional Billing                       28
# Other                                       16
# Private Insurance/Employee Health Plan      15
# Do Not Bill - Pharma                         5
# Clinical Trial : US                          3
# Patient Self-Pay                             2
# Research : US                                1
# DirectBill : US                              1
# ...

# %%
df["FOC"].isna().sum()/len(df)
# Out:
# 0.7717900133749442

# %%
df.loc[4:8, "Date"]
# Out:
# 4   2015-04-13
# 5   2015-04-16
# 6   2015-04-16
# 7   2015-05-14
# 8   2015-06-01
# Name: Date, dtype: datetime64[ns]
